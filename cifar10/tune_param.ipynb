# %%
from functools import partial
import numpy as np
import os
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
from torch.utils.data import random_split
import torchvision
import torchvision.transforms as transforms
from torch.utils.data import Dataset, TensorDataset
from torch.autograd import Variable
from ray import tune
from ray.tune import CLIReporter
from ray.tune.schedulers import ASHAScheduler
from resnet import ResNet18

# %%
exp_root = "/data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10"

# %%
def load_data():
    transform_train = transforms.Compose([
        transforms.RandomCrop(32, padding=4),
        transforms.RandomHorizontalFlip(),
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    transform_test = transforms.Compose([
        transforms.ToTensor(),
        transforms.Normalize((0.4914, 0.4822, 0.4465), (0.2023, 0.1994, 0.2010)),
    ])

    trainset = torchvision.datasets.CIFAR10(
        root='/data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/data', train=True, download=True, transform=transform_train)

    testset = torchvision.datasets.CIFAR10(
        root='/data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/data', train=False, download=True, transform=transform_test)

    return trainset, testset

# %%
trainset, _ = load_data()
trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=8,
        shuffle=True,
        num_workers=8)
net = ResNet18()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.01, momentum=0.9)
for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs, labels
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        if i > 5:
            print("training works")
            break
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# training works

# %%
def train_net(config, checkpoint_dir=None, data_dir=None):
    net = ResNet18()

    device = "cpu"
    if torch.cuda.is_available():
        device = "cuda:0"
        if torch.cuda.device_count() > 1:
            net = nn.DataParallel(net)
    net.to(device)

    criterion = nn.CrossEntropyLoss()
    optimizer = optim.SGD(net.parameters(), lr=config["lr"], momentum=0.9)

    if checkpoint_dir:
        model_state, optimizer_state = torch.load(os.path.join(checkpoint_dir, "checkpoint"))
        net.load_state_dict(model_state)
        optimizer.load_state_dict(optimizer_state)

    trainset, _ = load_data()

    test_abs = int(len(trainset) * 0.8)
    train_subset, val_subset = random_split(trainset, [test_abs, len(trainset) - test_abs])

    trainloader = torch.utils.data.DataLoader(
        train_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)
    valloader = torch.utils.data.DataLoader(
        val_subset,
        batch_size=int(config["batch_size"]),
        shuffle=True,
        num_workers=8)

    for epoch in range(10):  # loop over the dataset multiple times
        print("Training started...")
        running_loss = 0.0
        epoch_steps = 0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.to(device), labels.to(device)

            # zero the parameter gradients
            optimizer.zero_grad()

            # forward + backward + optimize
            outputs = net(inputs)
            loss = criterion(outputs, labels)
            loss.backward()
            optimizer.step()

            # print statistics
            running_loss += loss.item()
            epoch_steps += 1
            if i % 2000 == 1999:  # print every 2000 mini-batches
                print("[%d, %5d] loss: %.3f" % (epoch + 1, i + 1, running_loss / epoch_steps))
                running_loss = 0.0

        # Validation loss
        val_loss = 0.0
        val_steps = 0
        total = 0
        correct = 0
        for i, data in enumerate(valloader, 0):
            with torch.no_grad():
                inputs, labels = data
                inputs, labels = inputs.to(device), labels.to(device)

                outputs = net(inputs)
                _, predicted = torch.max(outputs.data, 1)
                total += labels.size(0)
                correct += (predicted == labels).sum().item()

                loss = criterion(outputs, labels)
                val_loss += loss.cpu().numpy()
                val_steps += 1

        with tune.checkpoint_dir(epoch) as checkpoint_dir:
            path = os.path.join(checkpoint_dir, "checkpoint")
            torch.save((net.state_dict(), optimizer.state_dict()), path)

        tune.report(loss=(val_loss / val_steps), accuracy=correct / total)
    print("Finished Training")

# %%
def test_accuracy(net, device="cpu"):
    _, testset = load_data()

    testloader = torch.utils.data.DataLoader(testset, batch_size=4, shuffle=False, num_workers=2)

    correct = 0
    total = 0
    with torch.no_grad():
        for data in testloader:
            images, labels = data
            images, labels = images.to(device), labels.to(device)
            outputs = net(images)
            _, predicted = torch.max(outputs.data, 1)
            total += labels.size(0)
            correct += (predicted == labels).sum().item()

    return correct / total

# %%
data_dir = "network_tune"
config = {
    "lr": tune.loguniform(1e-4, 1e-1),
    "batch_size": tune.choice([2, 16, 64, 128, 512])
}
scheduler = ASHAScheduler(
    metric="loss",
    mode="min",
    max_t=10, #not sure
    grace_period=1,
    reduction_factor=2)
reporter = CLIReporter(
    parameter_columns=["lr", "batch_size"],
    metric_columns=["loss", "accuracy", "training_iteration"])
result = tune.run(
    partial(train_net, data_dir=data_dir),
    local_dir = './network_tune',
    name='resnet18_cifar10',
    resources_per_trial={"cpu": 8, "gpu": 1},
    config=config,
    num_samples=20, # not sure
    scheduler=scheduler,
    progress_reporter=reporter)

best_trial = result.get_best_trial("loss", "min", "last")
print("Best trial config: {}".format(best_trial.config))
print("Best trial final validation loss: {}".format(best_trial.last_result["loss"]))
print("Best trial final validation accuracy: {}".format(best_trial.last_result["accuracy"]))
# Out:
# 2021-05-06 18:44:54,839	INFO services.py:1174 -- View the Ray dashboard at http://127.0.0.1:8265
# 2021-05-06 18:44:57,341	WARNING experiment.py:292 -- No name detected on trainable. Using DEFAULT.
# 2021-05-06 18:44:57,343	INFO registry.py:65 -- Detected unknown callable for trainable. Converting to class.
# == Status ==
# Memory usage on this node: 27.7/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: None
# Resources requested: 8/64 CPUs, 1/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 1/20 (1 RUNNING)
# +---------------------+----------+-------+-------------+--------------+
# | Trial name          | status   | loc   |          lr |   batch_size |
# |---------------------+----------+-------+-------------+--------------|
# | DEFAULT_6429b_00000 | RUNNING  |       | 0.000174246 |          128 |
# +---------------------+----------+-------+-------------+--------------+
#
#
# (pid=58040) Files already downloaded and verified
# (pid=58040) Files already downloaded and verified
# (pid=58040) Training started...
# (pid=58037) Files already downloaded and verified
# (pid=58037) Files already downloaded and verified
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.3332
#   date: 2021-05-06_18-46-09
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 1
#   loss: 1.7931293234040466
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 70.13935256004333
#   time_this_iter_s: 70.13935256004333
#   time_total_s: 70.13935256004333
#   timestamp: 1620319569
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.7931293234040466
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.79313 |     0.3332 |                    1 |
# | DEFAULT_6429b_00001 | RUNNING  |                    | 0.00599751  |           64 |         |            |                      |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |         |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.5949
#   date: 2021-05-06_18-46-22
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 1
#   loss: 1.1350787916001241
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 78.64913845062256
#   time_this_iter_s: 78.64913845062256
#   time_total_s: 78.64913845062256
#   timestamp: 1620319582
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: None | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.79313 |     0.3332 |                    1 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 1.13508 |     0.5949 |                    1 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |         |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.4053
#   date: 2021-05-06_18-47-11
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 2
#   loss: 1.595167719865147
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 132.33121538162231
#   time_this_iter_s: 62.19186282157898
#   time_total_s: 132.33121538162231
#   timestamp: 1620319631
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.595167719865147 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.59517 |     0.4053 |                    2 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 1.13508 |     0.5949 |                    1 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |         |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.6962
#   date: 2021-05-06_18-47-35
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 2
#   loss: 0.848339515886489
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 150.96845197677612
#   time_this_iter_s: 72.31931352615356
#   time_total_s: 150.96845197677612
#   timestamp: 1620319655
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.59517 |     0.4053 |                    2 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.84834 |     0.6962 |                    2 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |         |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.4602
#   date: 2021-05-06_18-48-15
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 3
#   loss: 1.4660271345814573
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 195.95348453521729
#   time_this_iter_s: 63.62226915359497
#   time_total_s: 195.95348453521729
#   timestamp: 1620319695
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |    loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.46603 |     0.4602 |                    3 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.84834 |     0.6962 |                    2 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |         |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+---------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.7421
#   date: 2021-05-06_18-48-46
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 3
#   loss: 0.7433446417948243
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 222.34375071525574
#   time_this_iter_s: 71.37529873847961
#   time_total_s: 222.34375071525574
#   timestamp: 1620319726
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: None | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.46603  |     0.4602 |                    3 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.743345 |     0.7421 |                    3 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.5048
#   date: 2021-05-06_18-49-17
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 4
#   loss: 1.3607648988313312
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 257.9565553665161
#   time_this_iter_s: 62.00307083129883
#   time_total_s: 257.9565553665161
#   timestamp: 1620319757
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -1.3607648988313312 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.36076  |     0.5048 |                    4 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.743345 |     0.7421 |                    3 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.7807
#   date: 2021-05-06_18-49-58
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 4
#   loss: 0.6251521693293456
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 293.7092487812042
#   time_this_iter_s: 71.36549806594849
#   time_total_s: 293.7092487812042
#   timestamp: 1620319798
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.36076  |     0.5048 |                    4 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.625152 |     0.7807 |                    4 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.5316
#   date: 2021-05-06_18-50-20
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 5
#   loss: 1.2861004886747915
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 320.9977881908417
#   time_this_iter_s: 63.04123282432556
#   time_total_s: 320.9977881908417
#   timestamp: 1620319820
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.2861   |     0.5316 |                    5 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.625152 |     0.7807 |                    4 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8028
#   date: 2021-05-06_18-51-09
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 5
#   loss: 0.5721829144438361
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 365.3671042919159
#   time_this_iter_s: 71.65785551071167
#   time_total_s: 365.3671042919159
#   timestamp: 1620319869
#   timesteps_since_restore: 0
#   training_iteration: 5
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.2861   |     0.5316 |                    5 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.572183 |     0.8028 |                    5 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.5573
#   date: 2021-05-06_18-51-22
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 6
#   loss: 1.2228061179571514
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 383.48828291893005
#   time_this_iter_s: 62.49049472808838
#   time_total_s: 383.48828291893005
#   timestamp: 1620319882
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.22281  |     0.5573 |                    6 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.572183 |     0.8028 |                    5 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8211
#   date: 2021-05-06_18-52-22
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 6
#   loss: 0.5290235165198138
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 438.1036846637726
#   time_this_iter_s: 72.73658037185669
#   time_total_s: 438.1036846637726
#   timestamp: 1620319942
#   timesteps_since_restore: 0
#   training_iteration: 6
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: None | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.22281  |     0.5573 |                    6 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.529024 |     0.8211 |                    6 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.5849
#   date: 2021-05-06_18-52-24
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 7
#   loss: 1.1624811020078538
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 445.5227026939392
#   time_this_iter_s: 62.034419775009155
#   time_total_s: 445.5227026939392
#   timestamp: 1620319944
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 6429b_00000
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.6091
#   date: 2021-05-06_18-53-28
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 8
#   loss: 1.1173476516445981
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 509.43172216415405
#   time_this_iter_s: 63.909019470214844
#   time_total_s: 509.43172216415405
#   timestamp: 1620320008
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -1.1173476516445981 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.11735  |     0.6091 |                    8 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.529024 |     0.8211 |                    6 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8299
#   date: 2021-05-06_18-53-34
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 7
#   loss: 0.49068286141772177
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 510.20528054237366
#   time_this_iter_s: 72.10159587860107
#   time_total_s: 510.20528054237366
#   timestamp: 1620320014
#   timesteps_since_restore: 0
#   training_iteration: 7
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -1.1173476516445981 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.11735  |     0.6091 |                    8 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.490683 |     0.8299 |                    7 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.6185
#   date: 2021-05-06_18-54-31
#   done: false
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 9
#   loss: 1.0620151313045356
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 571.8448278903961
#   time_this_iter_s: 62.413105726242065
#   time_total_s: 571.8448278903961
#   timestamp: 1620320071
#   timesteps_since_restore: 0
#   training_iteration: 9
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -1.1173476516445981 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.06202  |     0.6185 |                    9 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.490683 |     0.8299 |                    7 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58040) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8376
#   date: 2021-05-06_18-54-45
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 8
#   loss: 0.46953365671786534
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 581.2085931301117
#   time_this_iter_s: 71.00331258773804
#   time_total_s: 581.2085931301117
#   timestamp: 1620320085
#   timesteps_since_restore: 0
#   training_iteration: 8
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=0
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.06202  |     0.6185 |                    9 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.469534 |     0.8376 |                    8 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# Result for DEFAULT_6429b_00000:
#   accuracy: 0.6377
#   date: 2021-05-06_18-55-34
#   done: true
#   experiment_id: 46d6dd702df64288a0c6ae465bab0db1
#   hostname: dpl20
#   iterations_since_restore: 10
#   loss: 1.0153952580464036
#   node_ip: 10.116.44.44
#   pid: 58040
#   should_checkpoint: true
#   time_since_restore: 635.1425268650055
#   time_this_iter_s: 63.297698974609375
#   time_total_s: 635.1425268650055
#   timestamp: 1620320134
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 6429b_00000
#
# == Status ==
# Memory usage on this node: 33.9/754.6 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 3/20 (1 PENDING, 2 RUNNING)
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status   | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | RUNNING  | 10.116.44.44:58040 | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | RUNNING  | 10.116.44.44:58037 | 0.00599751  |           64 | 0.469534 |     0.8376 |                    8 |
# | DEFAULT_6429b_00002 | PENDING  |                    | 0.00644651  |            2 |          |            |                      |
# +---------------------+----------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58154) Files already downloaded and verified
# (pid=58154) Files already downloaded and verified
# (pid=58154) Training started...
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8501
#   date: 2021-05-06_18-55-56
#   done: false
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 9
#   loss: 0.43425226752545426
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 652.4890036582947
#   time_this_iter_s: 71.28041052818298
#   time_total_s: 652.4890036582947
#   timestamp: 1620320156
#   timesteps_since_restore: 0
#   training_iteration: 9
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=1
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 4/20 (1 PENDING, 2 RUNNING, 1 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00001 | RUNNING    | 10.116.44.44:58037 | 0.00599751  |           64 | 0.434252 |     0.8501 |                    9 |
# | DEFAULT_6429b_00002 | RUNNING    |                    | 0.00644651  |            2 |          |            |                      |
# | DEFAULT_6429b_00003 | PENDING    |                    | 0.000580661 |           64 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58037) Training started...
# (pid=58154) [1,  2000] loss: 2.453
# Result for DEFAULT_6429b_00001:
#   accuracy: 0.8528
#   date: 2021-05-06_18-57-09
#   done: true
#   experiment_id: 3617e415109d4d99a887af6c681c1c00
#   hostname: dpl20
#   iterations_since_restore: 10
#   loss: 0.4284150559621252
#   node_ip: 10.116.44.44
#   pid: 58037
#   should_checkpoint: true
#   time_since_restore: 725.4212079048157
#   time_this_iter_s: 72.932204246521
#   time_total_s: 725.4212079048157
#   timestamp: 1620320229
#   timesteps_since_restore: 0
#   training_iteration: 10
#   trial_id: 6429b_00001
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.4641040575020854
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 4/20 (1 PENDING, 2 RUNNING, 1 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00001 | RUNNING    | 10.116.44.44:58037 | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# | DEFAULT_6429b_00002 | RUNNING    |                    | 0.00644651  |            2 |          |            |                      |
# | DEFAULT_6429b_00003 | PENDING    |                    | 0.000580661 |           64 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58154) [1,  4000] loss: 1.077
# (pid=58138) Files already downloaded and verified
# (pid=58138) Files already downloaded and verified
# (pid=58138) Training started...
# (pid=58154) [1,  6000] loss: 0.668
# Result for DEFAULT_6429b_00003:
#   accuracy: 0.4975
#   date: 2021-05-06_18-58-32
#   done: false
#   experiment_id: 31288f97a4144f16b198c61fbf0abeb4
#   hostname: dpl20
#   iterations_since_restore: 1
#   loss: 1.3862113231306623
#   node_ip: 10.116.44.44
#   pid: 58138
#   should_checkpoint: true
#   time_since_restore: 80.50038290023804
#   time_this_iter_s: 80.50038290023804
#   time_total_s: 80.50038290023804
#   timestamp: 1620320312
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6429b_00003
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.2217536178758182 | Iter 1.000: -1.3862113231306623
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 5/20 (1 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00002 | RUNNING    |                    | 0.00644651  |            2 |          |            |                      |
# | DEFAULT_6429b_00003 | RUNNING    | 10.116.44.44:58138 | 0.000580661 |           64 | 1.38621  |     0.4975 |                    1 |
# | DEFAULT_6429b_00004 | PENDING    |                    | 0.00211571  |            2 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58138) Training started...
# (pid=58154) [1,  8000] loss: 0.479
# (pid=58154) [1, 10000] loss: 0.370
# Result for DEFAULT_6429b_00003:
#   accuracy: 0.6062
#   date: 2021-05-06_18-59-45
#   done: false
#   experiment_id: 31288f97a4144f16b198c61fbf0abeb4
#   hostname: dpl20
#   iterations_since_restore: 2
#   loss: 1.1187796102967231
#   node_ip: 10.116.44.44
#   pid: 58138
#   should_checkpoint: true
#   time_since_restore: 152.9889576435089
#   time_this_iter_s: 72.48857474327087
#   time_total_s: 152.9889576435089
#   timestamp: 1620320385
#   timesteps_since_restore: 0
#   training_iteration: 2
#   trial_id: 6429b_00003
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.1187796102967231 | Iter 1.000: -1.3862113231306623
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 5/20 (1 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00002 | RUNNING    |                    | 0.00644651  |            2 |          |            |                      |
# | DEFAULT_6429b_00003 | RUNNING    | 10.116.44.44:58138 | 0.000580661 |           64 | 1.11878  |     0.6062 |                    2 |
# | DEFAULT_6429b_00004 | PENDING    |                    | 0.00211571  |            2 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58138) Training started...
# (pid=58154) [1, 12000] loss: 0.299
# (pid=58154) [1, 14000] loss: 0.247
# Result for DEFAULT_6429b_00003:
#   accuracy: 0.6622
#   date: 2021-05-06_19-00-58
#   done: false
#   experiment_id: 31288f97a4144f16b198c61fbf0abeb4
#   hostname: dpl20
#   iterations_since_restore: 3
#   loss: 0.9544096953549962
#   node_ip: 10.116.44.44
#   pid: 58138
#   should_checkpoint: true
#   time_since_restore: 226.58074688911438
#   time_this_iter_s: 73.59178924560547
#   time_total_s: 226.58074688911438
#   timestamp: 1620320458
#   timesteps_since_restore: 0
#   training_iteration: 3
#   trial_id: 6429b_00003
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.9929585340803384 | Iter 2.000: -1.1187796102967231 | Iter 1.000: -1.3862113231306623
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 5/20 (1 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00002 | RUNNING    |                    | 0.00644651  |            2 |          |            |                      |
# | DEFAULT_6429b_00003 | RUNNING    | 10.116.44.44:58138 | 0.000580661 |           64 | 0.95441  |     0.6622 |                    3 |
# | DEFAULT_6429b_00004 | PENDING    |                    | 0.00211571  |            2 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58138) Training started...
# (pid=58154) [1, 16000] loss: 0.212
# Result for DEFAULT_6429b_00003:
#   accuracy: 0.7066
#   date: 2021-05-06_19-02-11
#   done: false
#   experiment_id: 31288f97a4144f16b198c61fbf0abeb4
#   hostname: dpl20
#   iterations_since_restore: 4
#   loss: 0.8512680777318918
#   node_ip: 10.116.44.44
#   pid: 58138
#   should_checkpoint: true
#   time_since_restore: 299.7681324481964
#   time_this_iter_s: 73.18738555908203
#   time_total_s: 299.7681324481964
#   timestamp: 1620320531
#   timesteps_since_restore: 0
#   training_iteration: 4
#   trial_id: 6429b_00003
#
# == Status ==
# Memory usage on this node: 33.8/754.6 GiB
# Using AsyncHyperBand: num_stopped=2
# Bracket: Iter 8.000: -0.7934406541812318 | Iter 4.000: -0.8512680777318918 | Iter 2.000: -1.1187796102967231 | Iter 1.000: -1.3862113231306623
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 5/20 (1 PENDING, 2 RUNNING, 2 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# ...
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00017 | RUNNING    | 10.116.44.44:58143 | 0.00677474  |           16 | 0.444166 |     0.8472 |                   10 |
# | DEFAULT_6429b_00018 | RUNNING    |                    | 0.0513153   |            2 |          |            |                      |
# | DEFAULT_6429b_00019 | PENDING    |                    | 0.00800969  |            2 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# | DEFAULT_6429b_00002 | TERMINATED |                    | 0.00644651  |            2 | 1.54478  |     0.4291 |                    1 |
# | DEFAULT_6429b_00003 | TERMINATED |                    | 0.000580661 |           64 | 0.577077 |     0.8064 |                   10 |
# | DEFAULT_6429b_00004 | TERMINATED |                    | 0.00211571  |            2 | 1.15313  |     0.5994 |                    2 |
# | DEFAULT_6429b_00005 | TERMINATED |                    | 0.00355226  |          512 | 1.49581  |     0.4513 |                    1 |
# | DEFAULT_6429b_00006 | TERMINATED |                    | 0.00245204  |          128 | 0.493521 |     0.8303 |                   10 |
# | DEFAULT_6429b_00007 | TERMINATED |                    | 0.00808965  |          512 | 1.12634  |     0.598  |                    2 |
# | DEFAULT_6429b_00008 | TERMINATED |                    | 0.0851466   |          512 | 1.73112  |     0.3432 |                    1 |
# | DEFAULT_6429b_00009 | TERMINATED |                    | 0.000719879 |          512 | 1.8293   |     0.3241 |                    1 |
# | DEFAULT_6429b_00010 | TERMINATED |                    | 0.0147445   |          128 | 0.43188  |     0.8516 |                   10 |
# | DEFAULT_6429b_00011 | TERMINATED |                    | 0.0243757   |            2 | 1.697    |     0.3769 |                    1 |
# | DEFAULT_6429b_00012 | TERMINATED |                    | 0.01585     |           16 | 1.48507  |     0.4622 |                    1 |
# | DEFAULT_6429b_00013 | TERMINATED |                    | 0.0001087   |           64 | 1.74506  |     0.3488 |                    1 |
# | DEFAULT_6429b_00014 | TERMINATED |                    | 0.0517242   |          128 | 0.455967 |     0.8423 |                   10 |
# | DEFAULT_6429b_00015 | TERMINATED |                    | 0.000344874 |          512 | 1.95874  |     0.2816 |                    1 |
# | DEFAULT_6429b_00016 | TERMINATED |                    | 0.0322323   |          512 | 1.20304  |     0.5725 |                    2 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58099) Files already downloaded and verified
# (pid=58099) Files already downloaded and verified
# (pid=58099) Training started...
# (pid=58020) [1, 18000] loss: 0.215
# (pid=58099) [1,  2000] loss: 2.491
# (pid=58020) [1, 20000] loss: 0.189
# (pid=58099) [1,  4000] loss: 1.114
# Result for DEFAULT_6429b_00018:
#   accuracy: 0.3045
#   date: 2021-05-06_19-47-27
#   done: true
#   experiment_id: 0d4f975abbb842d8a7cb6f3d33d15941
#   hostname: dpl20
#   iterations_since_restore: 1
#   loss: 1.8674206000328064
#   node_ip: 10.116.44.44
#   pid: 58020
#   should_checkpoint: true
#   time_since_restore: 459.12366104125977
#   time_this_iter_s: 459.12366104125977
#   time_total_s: 459.12366104125977
#   timestamp: 1620323247
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6429b_00018
#
# == Status ==
# Memory usage on this node: 34.6/754.6 GiB
# Using AsyncHyperBand: num_stopped=19
# Bracket: Iter 8.000: -0.5059078049056137 | Iter 4.000: -0.7324895179724391 | Iter 2.000: -1.0640824724183702 | Iter 1.000: -1.4850679999351502
# Resources requested: 16/64 CPUs, 2/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 20/20 (2 RUNNING, 18 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00018 | RUNNING    | 10.116.44.44:58020 | 0.0513153   |            2 | 1.86742  |     0.3045 |                    1 |
# | DEFAULT_6429b_00019 | RUNNING    |                    | 0.00800969  |            2 |          |            |                      |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# | DEFAULT_6429b_00002 | TERMINATED |                    | 0.00644651  |            2 | 1.54478  |     0.4291 |                    1 |
# | DEFAULT_6429b_00003 | TERMINATED |                    | 0.000580661 |           64 | 0.577077 |     0.8064 |                   10 |
# | DEFAULT_6429b_00004 | TERMINATED |                    | 0.00211571  |            2 | 1.15313  |     0.5994 |                    2 |
# | DEFAULT_6429b_00005 | TERMINATED |                    | 0.00355226  |          512 | 1.49581  |     0.4513 |                    1 |
# | DEFAULT_6429b_00006 | TERMINATED |                    | 0.00245204  |          128 | 0.493521 |     0.8303 |                   10 |
# | DEFAULT_6429b_00007 | TERMINATED |                    | 0.00808965  |          512 | 1.12634  |     0.598  |                    2 |
# | DEFAULT_6429b_00008 | TERMINATED |                    | 0.0851466   |          512 | 1.73112  |     0.3432 |                    1 |
# | DEFAULT_6429b_00009 | TERMINATED |                    | 0.000719879 |          512 | 1.8293   |     0.3241 |                    1 |
# | DEFAULT_6429b_00010 | TERMINATED |                    | 0.0147445   |          128 | 0.43188  |     0.8516 |                   10 |
# | DEFAULT_6429b_00011 | TERMINATED |                    | 0.0243757   |            2 | 1.697    |     0.3769 |                    1 |
# | DEFAULT_6429b_00012 | TERMINATED |                    | 0.01585     |           16 | 1.48507  |     0.4622 |                    1 |
# | DEFAULT_6429b_00013 | TERMINATED |                    | 0.0001087   |           64 | 1.74506  |     0.3488 |                    1 |
# | DEFAULT_6429b_00014 | TERMINATED |                    | 0.0517242   |          128 | 0.455967 |     0.8423 |                   10 |
# | DEFAULT_6429b_00015 | TERMINATED |                    | 0.000344874 |          512 | 1.95874  |     0.2816 |                    1 |
# | DEFAULT_6429b_00016 | TERMINATED |                    | 0.0322323   |          512 | 1.20304  |     0.5725 |                    2 |
# | DEFAULT_6429b_00017 | TERMINATED |                    | 0.00677474  |           16 | 0.444166 |     0.8472 |                   10 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# (pid=58099) [1,  6000] loss: 0.708
# (pid=58099) [1,  8000] loss: 0.508
# (pid=58099) [1, 10000] loss: 0.393
# (pid=58099) [1, 12000] loss: 0.312
# (pid=58099) [1, 14000] loss: 0.258
# (pid=58099) [1, 16000] loss: 0.218
# (pid=58099) [1, 18000] loss: 0.192
# (pid=58099) [1, 20000] loss: 0.166
# 2021-05-06 19:52:53,459	INFO tune.py:450 -- Total run time: 4079.62 seconds (4075.94 seconds for the tuning loop).
# Result for DEFAULT_6429b_00019:
#   accuracy: 0.3822
#   date: 2021-05-06_19-52-53
#   done: true
#   experiment_id: 310546b08415423fa4019a43fb400abf
#   hostname: dpl20
#   iterations_since_restore: 1
#   loss: 1.6884864147007466
#   node_ip: 10.116.44.44
#   pid: 58099
#   should_checkpoint: true
#   time_since_restore: 444.35638976097107
#   time_this_iter_s: 444.35638976097107
#   time_total_s: 444.35638976097107
#   timestamp: 1620323573
#   timesteps_since_restore: 0
#   training_iteration: 1
#   trial_id: 6429b_00019
#
# == Status ==
# Memory usage on this node: 34.1/754.6 GiB
# Using AsyncHyperBand: num_stopped=20
# Bracket: Iter 8.000: -0.5059078049056137 | Iter 4.000: -0.7324895179724391 | Iter 2.000: -1.0640824724183702 | Iter 1.000: -1.490436634707451
# Resources requested: 8/64 CPUs, 1/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 20/20 (1 RUNNING, 19 TERMINATED)
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc                |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00019 | RUNNING    | 10.116.44.44:58099 | 0.00800969  |            2 | 1.68849  |     0.3822 |                    1 |
# | DEFAULT_6429b_00000 | TERMINATED |                    | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |                    | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# | DEFAULT_6429b_00002 | TERMINATED |                    | 0.00644651  |            2 | 1.54478  |     0.4291 |                    1 |
# | DEFAULT_6429b_00003 | TERMINATED |                    | 0.000580661 |           64 | 0.577077 |     0.8064 |                   10 |
# | DEFAULT_6429b_00004 | TERMINATED |                    | 0.00211571  |            2 | 1.15313  |     0.5994 |                    2 |
# | DEFAULT_6429b_00005 | TERMINATED |                    | 0.00355226  |          512 | 1.49581  |     0.4513 |                    1 |
# | DEFAULT_6429b_00006 | TERMINATED |                    | 0.00245204  |          128 | 0.493521 |     0.8303 |                   10 |
# | DEFAULT_6429b_00007 | TERMINATED |                    | 0.00808965  |          512 | 1.12634  |     0.598  |                    2 |
# | DEFAULT_6429b_00008 | TERMINATED |                    | 0.0851466   |          512 | 1.73112  |     0.3432 |                    1 |
# | DEFAULT_6429b_00009 | TERMINATED |                    | 0.000719879 |          512 | 1.8293   |     0.3241 |                    1 |
# | DEFAULT_6429b_00010 | TERMINATED |                    | 0.0147445   |          128 | 0.43188  |     0.8516 |                   10 |
# | DEFAULT_6429b_00011 | TERMINATED |                    | 0.0243757   |            2 | 1.697    |     0.3769 |                    1 |
# | DEFAULT_6429b_00012 | TERMINATED |                    | 0.01585     |           16 | 1.48507  |     0.4622 |                    1 |
# | DEFAULT_6429b_00013 | TERMINATED |                    | 0.0001087   |           64 | 1.74506  |     0.3488 |                    1 |
# | DEFAULT_6429b_00014 | TERMINATED |                    | 0.0517242   |          128 | 0.455967 |     0.8423 |                   10 |
# | DEFAULT_6429b_00015 | TERMINATED |                    | 0.000344874 |          512 | 1.95874  |     0.2816 |                    1 |
# | DEFAULT_6429b_00016 | TERMINATED |                    | 0.0322323   |          512 | 1.20304  |     0.5725 |                    2 |
# | DEFAULT_6429b_00017 | TERMINATED |                    | 0.00677474  |           16 | 0.444166 |     0.8472 |                   10 |
# | DEFAULT_6429b_00018 | TERMINATED |                    | 0.0513153   |            2 | 1.86742  |     0.3045 |                    1 |
# +---------------------+------------+--------------------+-------------+--------------+----------+------------+----------------------+
#
#
# == Status ==
# Memory usage on this node: 34.2/754.6 GiB
# Using AsyncHyperBand: num_stopped=20
# Bracket: Iter 8.000: -0.5059078049056137 | Iter 4.000: -0.7324895179724391 | Iter 2.000: -1.0640824724183702 | Iter 1.000: -1.490436634707451
# Resources requested: 0/64 CPUs, 0/2 GPUs, 0.0/542.72 GiB heap, 0.0/128.52 GiB objects (0/1.0 accelerator_type:V100S)
# Result logdir: /data/user/ladilova/fed_colearning/FederatedLearningViaCoTraining/cifar10/network_tune/resnet18_cifar10
# Number of trials: 20/20 (20 TERMINATED)
# +---------------------+------------+-------+-------------+--------------+----------+------------+----------------------+
# | Trial name          | status     | loc   |          lr |   batch_size |     loss |   accuracy |   training_iteration |
# |---------------------+------------+-------+-------------+--------------+----------+------------+----------------------|
# | DEFAULT_6429b_00000 | TERMINATED |       | 0.000174246 |          128 | 1.0154   |     0.6377 |                   10 |
# | DEFAULT_6429b_00001 | TERMINATED |       | 0.00599751  |           64 | 0.428415 |     0.8528 |                   10 |
# | DEFAULT_6429b_00002 | TERMINATED |       | 0.00644651  |            2 | 1.54478  |     0.4291 |                    1 |
# | DEFAULT_6429b_00003 | TERMINATED |       | 0.000580661 |           64 | 0.577077 |     0.8064 |                   10 |
# | DEFAULT_6429b_00004 | TERMINATED |       | 0.00211571  |            2 | 1.15313  |     0.5994 |                    2 |
# | DEFAULT_6429b_00005 | TERMINATED |       | 0.00355226  |          512 | 1.49581  |     0.4513 |                    1 |
# | DEFAULT_6429b_00006 | TERMINATED |       | 0.00245204  |          128 | 0.493521 |     0.8303 |                   10 |
# | DEFAULT_6429b_00007 | TERMINATED |       | 0.00808965  |          512 | 1.12634  |     0.598  |                    2 |
# | DEFAULT_6429b_00008 | TERMINATED |       | 0.0851466   |          512 | 1.73112  |     0.3432 |                    1 |
# | DEFAULT_6429b_00009 | TERMINATED |       | 0.000719879 |          512 | 1.8293   |     0.3241 |                    1 |
# | DEFAULT_6429b_00010 | TERMINATED |       | 0.0147445   |          128 | 0.43188  |     0.8516 |                   10 |
# | DEFAULT_6429b_00011 | TERMINATED |       | 0.0243757   |            2 | 1.697    |     0.3769 |                    1 |
# | DEFAULT_6429b_00012 | TERMINATED |       | 0.01585     |           16 | 1.48507  |     0.4622 |                    1 |
# | DEFAULT_6429b_00013 | TERMINATED |       | 0.0001087   |           64 | 1.74506  |     0.3488 |                    1 |
# | DEFAULT_6429b_00014 | TERMINATED |       | 0.0517242   |          128 | 0.455967 |     0.8423 |                   10 |
# | DEFAULT_6429b_00015 | TERMINATED |       | 0.000344874 |          512 | 1.95874  |     0.2816 |                    1 |
# | DEFAULT_6429b_00016 | TERMINATED |       | 0.0322323   |          512 | 1.20304  |     0.5725 |                    2 |
# | DEFAULT_6429b_00017 | TERMINATED |       | 0.00677474  |           16 | 0.444166 |     0.8472 |                   10 |
# | DEFAULT_6429b_00018 | TERMINATED |       | 0.0513153   |            2 | 1.86742  |     0.3045 |                    1 |
# | DEFAULT_6429b_00019 | TERMINATED |       | 0.00800969  |            2 | 1.68849  |     0.3822 |                    1 |
# +---------------------+------------+-------+-------------+--------------+----------+------------+----------------------+
#
#
# Best trial config: {'lr': 0.0059975141086397316, 'batch_size': 64}
# Best trial final validation loss: 0.4284150559621252
# Best trial final validation accuracy: 0.8528

# %% [raw]
# Best trial config: {'lr': 0.0059975141086397316, 'batch_size': 64}
# Best trial final validation loss: 0.4284150559621252
# Best trial final validation accuracy: 0.8528

# %%
trainset, _ = load_data()
trainloader = torch.utils.data.DataLoader(
        trainset,
        batch_size=64,
        shuffle=True,
        num_workers=8)
net = ResNet18()
criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=0.005, momentum=0.9)
for e in range(200):
    total = 0
    correct = 0
    train_loss = 0
    for i, data in enumerate(trainloader, 0):
        inputs, labels = data
        inputs, labels = inputs, labels
        optimizer.zero_grad()
        outputs = net(inputs)
        loss = criterion(outputs, labels)
        loss.backward()
        optimizer.step()
        
        train_loss += loss.item()
        _, predicted = outputs.max(1)
        total += labels.size(0)
        correct += predicted.eq(labels).sum().item()

    print('Epoch %d, Loss: %.3f | Acc: %.3f%% (%d/%d)' % (e, train_loss/(i+1), 100.*correct/total, correct, total))
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# Epoch 0, Loss: 1.411 | Acc: 48.440% (24220/50000)
# Epoch 1, Loss: 0.889 | Acc: 68.674% (34337/50000)
# Epoch 2, Loss: 0.690 | Acc: 75.978% (37989/50000)
# Epoch 3, Loss: 0.584 | Acc: 79.698% (39849/50000)
# Epoch 4, Loss: 0.507 | Acc: 82.342% (41171/50000)
# Epoch 5, Loss: 0.454 | Acc: 84.176% (42088/50000)
# Epoch 6, Loss: 0.410 | Acc: 85.712% (42856/50000)
# Epoch 7, Loss: 0.378 | Acc: 86.834% (43417/50000)
# Epoch 8, Loss: 0.349 | Acc: 87.988% (43994/50000)
# Epoch 9, Loss: 0.319 | Acc: 88.824% (44412/50000)
# Epoch 10, Loss: 0.292 | Acc: 89.950% (44975/50000)
# Epoch 11, Loss: 0.276 | Acc: 90.366% (45183/50000)
# Epoch 12, Loss: 0.262 | Acc: 90.970% (45485/50000)
# Epoch 13, Loss: 0.244 | Acc: 91.412% (45706/50000)
# Epoch 14, Loss: 0.224 | Acc: 92.242% (46121/50000)
# Epoch 15, Loss: 0.212 | Acc: 92.540% (46270/50000)
# Epoch 16, Loss: 0.199 | Acc: 93.138% (46569/50000)
# Epoch 17, Loss: 0.185 | Acc: 93.436% (46718/50000)
# Epoch 18, Loss: 0.174 | Acc: 93.854% (46927/50000)
# Epoch 19, Loss: 0.167 | Acc: 94.128% (47064/50000)
# Epoch 20, Loss: 0.156 | Acc: 94.462% (47231/50000)
# Epoch 21, Loss: 0.148 | Acc: 94.888% (47444/50000)
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-11-a8a755aae1c9> in <module>
#      18         outputs = net(inputs)
#      19         loss = criterion(outputs, labels)
# ---> 20         loss.backward()
#      21         optimizer.step()
#      22
#
# ~/anaconda3_new/envs/colearning/lib/python3.7/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph, inputs)
#     243                 create_graph=create_graph,
#     244                 inputs=inputs)
# --> 245         torch.autograd.backward(self, gradient, retain_graph, create_graph, inputs=inputs)
#     246
#     247     def register_hook(self, hook):
#
# ~/anaconda3_new/envs/colearning/lib/python3.7/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables, inputs)
#     145     Variable._execution_engine.run_backward(
#     146         tensors, grad_tensors_, retain_graph, create_graph, inputs,
# --> 147         allow_unreachable=True, accumulate_grad=True)  # allow_unreachable flag
#     148
#     149
#
# KeyboardInterrupt:
